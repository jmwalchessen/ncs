# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
images = np.log(np.load("temporary_schlather_samples.npy"))

# %%
images.shape
# Out:
# (10, 1024)

# %%
images = np.log(np.load("temporary_schlather_samples.npy"))
fig, ax = plt.subplots(1)
n = 32
ax.imshow(images[0,:].reshape((n,n), order = 'F'))
plt.show()
